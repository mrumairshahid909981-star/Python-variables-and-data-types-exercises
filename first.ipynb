# %% [markdown]
#  #VARIABLES AND DATATYPE

# %% [markdown]
# First code

# %%
print ("Hello world")
# Out:
# Hello world

# %% [markdown]
# variables and datatypes

# %%
a = 5
b = 8
sum = (a+b)
diff = (a-b)
print (sum , diff)
# Out:
# 13 -3

# %% [markdown]
# Create variables to store your name, age, and city, then print them

# %%
name = "MuhammadUmairShahid"
age = 21
city = "faisalabad"
print("Name :",name )
print("Age :" ,age )
print("City :",city )
# Out:
# Name : MuhammadUmairShahid
# Age : 21
# City : faisalabad

# %% [markdown]
# Take user input for a name and print a welcome message

# %%
Name = input("enter your name: ")
Age = input("enter your Age: ")
Number = input("enter your number: " )
print("thanks for enter name: ", Name )
print("thanks for enter age: ", Age )
print("thanks for enter number:", Number )
# Out:
# thanks for enter name:  muhammad
# thanks for enter age:  21
# thanks for enter number: 027272899

# %% [markdown]
# Swap the values of two variables.

# %%
a = 5
b = 6
temp = a
a = b
b = temp

print(a,b)
# Out:
# 6 5

# %% [markdown]
# Convert a string "25" into an integer and add 10 to it.

# %%
string = "25"
string =  int (string)
sum = string +10
print( sum)
print(type(string))
# Out:
# 35
# <class 'int'>

# %%
Name = input("enter your name: ")
Age = input("enter your Age: ")
Number = input("enter your number: " )
person = {
        "name":  Name, 
        "age": Age ,
        "number": Number 
}
print(person)
# Out:
# {'name': 'bbxnh', 'age': 'djdj', 'number': 'djd'}

# %%
person = {
    'name' : input("enter name "),
    'age' : input ("enter age"),
    'number' : input ("enter no")
}

print ("Name :", person["name"])
print("Age:" , person["age"])
print("No: ", person["number"])
# Out:
# Name : MUHAMMAD
# Age: 21
# No:  126384

# %% [markdown]
# Create a list of 5 favorite fruits and print the first and last fruit.

# %%
fruit1 = [" mango", "apple" ,"banan", "strawbeery" , "orange"]
print("fruit:" ,fruit1[0])
print("fruit:" ,fruit1[3])
# Out:
# fruit:  mango
# fruit: strawbeery

# %% [markdown]
# Store three numbers in variables and find their average.

# %%
no1 = 12
no2 = 14
no3 = 15
average = (no1+no2+no3/3)*100
print("Abverage =" , average )
# Out:
# Abverage = 3100.0

# %% [markdown]
# Challenge Questions
# Take two numbers as input and display their sum, difference, product, and quotient.

# %%
a = 3
b = 19

print("sum :", a + b)
print("diffrence :", a - b)
print("product :", a * b)
print("quotient :", a / b)
# Out:
# sum : 22
# diffrence : -16
# product : 57
# quotient : 0.15789473684210525

# %% [markdown]
# Store a person's details (name, age, GPA) in variables and print them in one sentence.

# %%
Name = "Muhammad umair shahid"
age = 21 
rollno = 2343
gpa = 3.2


print( "My name is =", Name ,"My age id =" , age , "My roll no is =", rollno , "My gpa is =" , gpa )
# Out:
# My name is = Muhammad umair shahid My age id = 21 My roll no is = 2343 My gpa is = 3.2

# %% [markdown]
# Convert temperature from Celsius to Fahrenheit using variables.

# %%
Celsius = float(input("enter tempretre") )
Fahrenheit = (Celsius * 9/5) + 32
print ("Fahrenheit ;" , Fahrenheit)
# Out:
# Fahrenheit ; 132.8

# %% [markdown]
# Calculate the area of a rectangle using variables for length and width.

# %%
length = float(input("enter length") )
width = float(input("enter width") )
print("rectangle area :" , length*width)
# Out:
# rectangle area : 92.0
